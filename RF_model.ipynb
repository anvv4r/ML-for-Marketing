# %%
# Import the required libraries
import sqlite3
import pandas as pd
import pickle
from statistics import mode
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.pipeline import Pipeline
from joblib import load
from joblib import dump

# %%
# Connect to the database
conn = sqlite3.connect('data.db')
cursor = conn.cursor()

# Query and joining all the tables in the database and obtain the data as a DataFrame
query = """
SELECT c.client_id, c.age, c.job, c.marital, c.education, c.gender,
       cp.has_deposits, cp.loan, cp.has_insurance, cp.has_mortgage,
       ice.poutcome,
       b.date, b.balance, b.currency
FROM client AS c
LEFT JOIN client_products  AS cp ON c.client_id = cp.client_id
LEFT JOIN inv_campaign_eval  AS ice ON c.client_id = ice.client_id
LEFT JOIN balances AS b ON c.client_id = b.client_id
"""
df = pd.read_sql_query(query, conn)
df
# Out:
#         client_id   age          job  marital  education gender has_deposits  \
# 0       249789938  38.0     services  married  secondary      M          yes
# 1       249789938  38.0     services  married  secondary      M          yes
# 2       249789938  38.0     services  married  secondary      M          yes
# 3       249789938  38.0     services  married  secondary      M          yes
# 4       249789938  38.0     services  married  secondary      M          yes
# ...           ...   ...          ...      ...        ...    ...          ...
# 290207  705801685  36.0  blue-collar   single  secondary      F          yes
# 290208  705801685  36.0  blue-collar   single  secondary      F          yes
# 290209  705801685  36.0  blue-collar   single  secondary      F          yes
# 290210  705801685  36.0  blue-collar   single  secondary      F          yes
# 290211  705801685  36.0  blue-collar   single  secondary      F          yes
#
#        loan has_insurance has_mortgage poutcome                        date  \
# 0        no             n           no  success  2022-06-21 16:21:15.291346
# 1        no             n           no  success  2022-07-05 16:21:15.291346
# 2        no             n           no  success  2022-07-19 16:21:15.291346
# 3        no             n           no  success  2022-08-02 16:21:15.291346
# 4        no             n           no  success  2022-08-16 16:21:15.291346
# ...     ...           ...          ...      ...                         ...
# 290207   no             n          yes  success  2023-04-11 16:22:46.440217
# 290208   no             n          yes  success  2023-04-25 16:22:46.440217
# 290209   no             n          yes  success  2023-05-09 16:22:46.440217
# 290210   no             n          yes  success  2023-05-23 16:22:46.440217
# 290211   no             n          yes  success  2023-06-06 16:22:46.440217
#
#             balance currency
# 0       2633.671253      CZK
# 1       2663.697443      CZK
# 2       2605.350108      CZK
# 3       2694.840314      CZK
# 4       2656.018182      CZK
# ...             ...      ...
# 290207    84.358039      CZK
# 290208     8.617271      CZK
# 290209    40.666162      CZK
# 290210   -13.947329      CZK
# 290211   -13.415755      CZK
#
# [290212 rows x 14 columns]

# %%
#Change the data types of the age and balance columns

def change_data_types(df):
    df['date'] = pd.to_datetime(df['date'])
    df['age'] = df['age'].astype(float)
    df['balance'] = df['balance'].astype(float)

    return df

df = change_data_types(df)
df
# Out:
#         client_id   age          job  marital  education gender has_deposits  \
# 0       249789938  38.0     services  married  secondary      M          yes
# 1       249789938  38.0     services  married  secondary      M          yes
# 2       249789938  38.0     services  married  secondary      M          yes
# 3       249789938  38.0     services  married  secondary      M          yes
# 4       249789938  38.0     services  married  secondary      M          yes
# ...           ...   ...          ...      ...        ...    ...          ...
# 290207  705801685  36.0  blue-collar   single  secondary      F          yes
# 290208  705801685  36.0  blue-collar   single  secondary      F          yes
# 290209  705801685  36.0  blue-collar   single  secondary      F          yes
# 290210  705801685  36.0  blue-collar   single  secondary      F          yes
# 290211  705801685  36.0  blue-collar   single  secondary      F          yes
#
#        loan has_insurance has_mortgage poutcome                       date  \
# 0        no             n           no  success 2022-06-21 16:21:15.291346
# 1        no             n           no  success 2022-07-05 16:21:15.291346
# 2        no             n           no  success 2022-07-19 16:21:15.291346
# 3        no             n           no  success 2022-08-02 16:21:15.291346
# 4        no             n           no  success 2022-08-16 16:21:15.291346
# ...     ...           ...          ...      ...                        ...
# 290207   no             n          yes  success 2023-04-11 16:22:46.440217
# 290208   no             n          yes  success 2023-04-25 16:22:46.440217
# 290209   no             n          yes  success 2023-05-09 16:22:46.440217
# 290210   no             n          yes  success 2023-05-23 16:22:46.440217
# 290211   no             n          yes  success 2023-06-06 16:22:46.440217
#
#             balance currency
# 0       2633.671253      CZK
# 1       2663.697443      CZK
# 2       2605.350108      CZK
# 3       2694.840314      CZK
# 4       2656.018182      CZK
# ...             ...      ...
# 290207    84.358039      CZK
# 290208     8.617271      CZK
# 290209    40.666162      CZK
# 290210   -13.947329      CZK
# 290211   -13.415755      CZK
#
# [290212 rows x 14 columns]

# %%
#CONVERTING THE BALANCE TO CZK
def convert_to_czk(row, currency):
    if currency == 'USD':
        return row['balance'] * usd_to_czk
    elif currency == 'EURO':
        return row['balance'] * euro_to_czk
    else:
        return row['balance']

usd_to_czk = 23.4  # replace with the current exchange rate
euro_to_czk = 25.32  # replace with the current exchange rate

df['balance'] = df.apply(lambda row: convert_to_czk(row, row['currency']), axis=1)
df
# Out:
#         client_id   age          job  marital  education gender has_deposits  \
# 0       249789938  38.0     services  married  secondary      M          yes
# 1       249789938  38.0     services  married  secondary      M          yes
# 2       249789938  38.0     services  married  secondary      M          yes
# 3       249789938  38.0     services  married  secondary      M          yes
# 4       249789938  38.0     services  married  secondary      M          yes
# ...           ...   ...          ...      ...        ...    ...          ...
# 290207  705801685  36.0  blue-collar   single  secondary      F          yes
# 290208  705801685  36.0  blue-collar   single  secondary      F          yes
# 290209  705801685  36.0  blue-collar   single  secondary      F          yes
# 290210  705801685  36.0  blue-collar   single  secondary      F          yes
# 290211  705801685  36.0  blue-collar   single  secondary      F          yes
#
#        loan has_insurance has_mortgage poutcome                       date  \
# 0        no             n           no  success 2022-06-21 16:21:15.291346
# 1        no             n           no  success 2022-07-05 16:21:15.291346
# 2        no             n           no  success 2022-07-19 16:21:15.291346
# 3        no             n           no  success 2022-08-02 16:21:15.291346
# 4        no             n           no  success 2022-08-16 16:21:15.291346
# ...     ...           ...          ...      ...                        ...
# 290207   no             n          yes  success 2023-04-11 16:22:46.440217
# 290208   no             n          yes  success 2023-04-25 16:22:46.440217
# 290209   no             n          yes  success 2023-05-09 16:22:46.440217
# 290210   no             n          yes  success 2023-05-23 16:22:46.440217
# 290211   no             n          yes  success 2023-06-06 16:22:46.440217
#
#             balance currency
# 0       2633.671253      CZK
# 1       2663.697443      CZK
# 2       2605.350108      CZK
# 3       2694.840314      CZK
# 4       2656.018182      CZK
# ...             ...      ...
# 290207    84.358039      CZK
# 290208     8.617271      CZK
# 290209    40.666162      CZK
# 290210   -13.947329      CZK
# 290211   -13.415755      CZK
#
# [290212 rows x 14 columns]

# %%
# Calculate the average spending for each client
def calculate_average_spending(df):
    # Sort the DataFrame
    df = df.sort_values(['client_id', 'date'])

    # Calculate the balance difference for each date
    df['balance_diff'] = df.groupby('client_id')['balance'].diff()

    # Calculate the average spending for each client
    average_spending = df.groupby('client_id')['balance_diff'].mean()

    # Map the average spending to the client_id in the original DataFrame
    df['average_spending'] = df['client_id'].map(average_spending)

    return df

df_spending = calculate_average_spending(df)
df_spending
# Out:
#          client_id   age          job   marital  education gender  \
# 265876   100070076  41.0   management  divorced   tertiary      M
# 265877   100070076  41.0   management  divorced   tertiary      M
# 265878   100070076  41.0   management  divorced   tertiary      M
# 265879   100070076  41.0   management  divorced   tertiary      M
# 265880   100070076  41.0   management  divorced   tertiary      M
# ...            ...   ...          ...       ...        ...    ...
# 232695  1999956516  32.0  blue-collar   married  secondary      M
# 232696  1999956516  32.0  blue-collar   married  secondary      M
# 232697  1999956516  32.0  blue-collar   married  secondary      M
# 232698  1999956516  32.0  blue-collar   married  secondary      M
# 232699  1999956516  32.0  blue-collar   married  secondary      M
#
#        has_deposits loan has_insurance has_mortgage poutcome  \
# 265876           no   no             n           no     None
# 265877           no   no             n           no     None
# 265878           no   no             n           no     None
# 265879           no   no             n           no     None
# 265880           no   no             n           no     None
# ...             ...  ...           ...          ...      ...
# 232695          yes   no             n          yes  failure
# 232696          yes   no             n          yes  failure
# 232697          yes   no             n          yes  failure
# 232698          yes   no             n          yes  failure
# 232699          yes   no             n          yes  failure
#
#                              date     balance currency  balance_diff  \
# 265876 2022-06-21 16:22:36.643827  361.807400      CZK           NaN
# 265877 2022-07-05 16:22:36.643827  113.142183      CZK   -248.665217
# 265878 2022-07-19 16:22:36.643827  148.537614      CZK     35.395431
# 265879 2022-08-02 16:22:36.643827  215.003236      CZK     66.465622
# 265880 2022-08-16 16:22:36.643827  129.477982      CZK    -85.525254
# ...                           ...         ...      ...           ...
# 232695 2023-04-11 16:22:24.006798  207.392088      CZK    -99.430220
# 232696 2023-04-25 16:22:24.006798  257.053986      CZK     49.661898
# 232697 2023-05-09 16:22:24.006798  271.478324      CZK     14.424338
# 232698 2023-05-23 16:22:24.006798  180.129715      CZK    -91.348609
# 232699 2023-06-06 16:22:24.006798  229.440915      CZK     49.311201
#
#         average_spending
# 265876         -7.454485
# 265877         -7.454485
# 265878         -7.454485
# 265879         -7.454485
# 265880         -7.454485
# ...                  ...
# 232695          2.536917
# 232696          2.536917
# 232697          2.536917
# 232698          2.536917
# 232699          2.536917
#
# [290212 rows x 16 columns]

# %%
# Select the latest balance for each client
def select_latest_balance(df_spending):
    # Sort by 'client_id' and 'date'
    df_spending = df_spending.sort_values(['client_id', 'date'])
    
    # Calculate the average balance for each client
    average_balance = df_spending.groupby('client_id')['balance'].mean()

    # Map the average balance to the client_id in the original DataFrame
    df_spending['average_balance'] = df_spending['client_id'].map(average_balance)
    
    # Drop duplicates, keeping only the last entry for each 'client_id'
    df_spending = df_spending.drop_duplicates('client_id', keep='last')
    
    return df_spending

df_balance = select_latest_balance(df_spending)
df_balance
# Out:
#          client_id   age          job   marital  education gender  \
# 265901   100070076  41.0   management  divorced   tertiary      M
# 175317   100141910  34.0   management    single   tertiary      F
# 191645   100207570  34.0   management    single   tertiary      F
# 43705    100488560  43.0       admin.    single  secondary      F
# 262703   100605013  21.0      student    single    primary      M
# ...            ...   ...          ...       ...        ...    ...
# 22879   1999463182  34.0  blue-collar   married  secondary      M
# 130363  1999499145  31.0   management    single   tertiary      F
# 87099   1999715381  24.0  blue-collar   married  secondary      M
# 89179   1999945413  39.0         None    single   tertiary      F
# 232699  1999956516  32.0  blue-collar   married  secondary      M
#
#        has_deposits loan has_insurance has_mortgage poutcome  \
# 265901           no   no             n           no     None
# 175317           no   no             n          yes     None
# 191645          yes   no             n           no     None
# 43705           yes   no             n           no  failure
# 262703          yes   no             y           no  success
# ...             ...  ...           ...          ...      ...
# 22879            no   no             n          yes     None
# 130363           no   no             n          yes     None
# 87099           yes   no             n          yes     None
# 89179           yes   no             n           no     None
# 232699          yes   no             n          yes  failure
#
#                              date      balance currency  balance_diff  \
# 265901 2023-06-06 16:22:36.643827   175.445269      CZK     29.953812
# 175317 2023-06-06 16:22:04.265177  2559.041192      CZK      9.340310
# 191645 2023-06-06 16:22:09.249972    94.055761      CZK    107.718168
# 43705  2023-06-06 16:21:25.597087   382.755389      CZK      6.380241
# 262703 2023-06-06 16:22:35.410449   369.476219      CZK   -140.446928
# ...                           ...          ...      ...           ...
# 22879  2023-06-06 16:21:20.742835  1146.101785      CZK   -165.302083
# 130363 2023-06-06 16:21:50.781726    30.830676      CZK     36.034384
# 87099  2023-06-06 16:21:36.964752   792.767525      CZK    136.046944
# 89179  2023-06-06 16:21:37.470159  5077.753230      CZK      3.199596
# 232699 2023-06-06 16:22:24.006798   229.440915      CZK     49.311201
#
#         average_spending  average_balance
# 265901         -7.454485       203.907928
# 175317          0.444639      2544.965438
# 191645          2.436701       -15.679495
# 43705           5.109879       381.488613
# 262703          0.039401       420.351449
# ...                  ...              ...
# 22879          -4.687871      1268.089349
# 130363         -0.482484        -4.751058
# 87099           6.663159       676.988885
# 89179          -3.010250      5047.496305
# 232699          2.536917       231.982319
#
# [11162 rows x 17 columns]

# %%
#fill the missing values in the 'job', 'marital', and 'education' columns with the mode
df_balance['job'] = df_balance['job'].fillna(mode(df_balance['job']))
df_balance['marital'] = df_balance['marital'].fillna(mode(df_balance['marital']))
df_balance['education'] = df_balance['education'].fillna(mode(df_balance['education']))
df_balance['age'] = df_balance['age'].fillna(df_balance['age'].mean())
df_balance
# Out:
#          client_id   age          job   marital  education gender  \
# 265901   100070076  41.0   management  divorced   tertiary      M
# 175317   100141910  34.0   management    single   tertiary      F
# 191645   100207570  34.0   management    single   tertiary      F
# 43705    100488560  43.0       admin.    single  secondary      F
# 262703   100605013  21.0      student    single    primary      M
# ...            ...   ...          ...       ...        ...    ...
# 22879   1999463182  34.0  blue-collar   married  secondary      M
# 130363  1999499145  31.0   management    single   tertiary      F
# 87099   1999715381  24.0  blue-collar   married  secondary      M
# 89179   1999945413  39.0   management    single   tertiary      F
# 232699  1999956516  32.0  blue-collar   married  secondary      M
#
#        has_deposits loan has_insurance has_mortgage poutcome  \
# 265901           no   no             n           no     None
# 175317           no   no             n          yes     None
# 191645          yes   no             n           no     None
# 43705           yes   no             n           no  failure
# 262703          yes   no             y           no  success
# ...             ...  ...           ...          ...      ...
# 22879            no   no             n          yes     None
# 130363           no   no             n          yes     None
# 87099           yes   no             n          yes     None
# 89179           yes   no             n           no     None
# 232699          yes   no             n          yes  failure
#
#                              date      balance currency  balance_diff  \
# 265901 2023-06-06 16:22:36.643827   175.445269      CZK     29.953812
# 175317 2023-06-06 16:22:04.265177  2559.041192      CZK      9.340310
# 191645 2023-06-06 16:22:09.249972    94.055761      CZK    107.718168
# 43705  2023-06-06 16:21:25.597087   382.755389      CZK      6.380241
# 262703 2023-06-06 16:22:35.410449   369.476219      CZK   -140.446928
# ...                           ...          ...      ...           ...
# 22879  2023-06-06 16:21:20.742835  1146.101785      CZK   -165.302083
# 130363 2023-06-06 16:21:50.781726    30.830676      CZK     36.034384
# 87099  2023-06-06 16:21:36.964752   792.767525      CZK    136.046944
# 89179  2023-06-06 16:21:37.470159  5077.753230      CZK      3.199596
# 232699 2023-06-06 16:22:24.006798   229.440915      CZK     49.311201
#
#         average_spending  average_balance
# 265901         -7.454485       203.907928
# 175317          0.444639      2544.965438
# 191645          2.436701       -15.679495
# 43705           5.109879       381.488613
# 262703          0.039401       420.351449
# ...                  ...              ...
# 22879          -4.687871      1268.089349
# 130363         -0.482484        -4.751058
# 87099           6.663159       676.988885
# 89179          -3.010250      5047.496305
# 232699          2.536917       231.982319
#
# [11162 rows x 17 columns]

# %%
#drop the date and currency columns
df_balance = df_balance.drop(columns=['date', 'currency'])

#drop the 'balance_diff' column
df_balance = df_balance.drop(columns=['balance_diff'])
df_balance
# Out:
#          client_id   age          job   marital  education gender  \
# 265901   100070076  41.0   management  divorced   tertiary      M
# 175317   100141910  34.0   management    single   tertiary      F
# 191645   100207570  34.0   management    single   tertiary      F
# 43705    100488560  43.0       admin.    single  secondary      F
# 262703   100605013  21.0      student    single    primary      M
# ...            ...   ...          ...       ...        ...    ...
# 22879   1999463182  34.0  blue-collar   married  secondary      M
# 130363  1999499145  31.0   management    single   tertiary      F
# 87099   1999715381  24.0  blue-collar   married  secondary      M
# 89179   1999945413  39.0   management    single   tertiary      F
# 232699  1999956516  32.0  blue-collar   married  secondary      M
#
#        has_deposits loan has_insurance has_mortgage poutcome      balance  \
# 265901           no   no             n           no     None   175.445269
# 175317           no   no             n          yes     None  2559.041192
# 191645          yes   no             n           no     None    94.055761
# 43705           yes   no             n           no  failure   382.755389
# 262703          yes   no             y           no  success   369.476219
# ...             ...  ...           ...          ...      ...          ...
# 22879            no   no             n          yes     None  1146.101785
# 130363           no   no             n          yes     None    30.830676
# 87099           yes   no             n          yes     None   792.767525
# 89179           yes   no             n           no     None  5077.753230
# 232699          yes   no             n          yes  failure   229.440915
#
#         average_spending  average_balance
# 265901         -7.454485       203.907928
# 175317          0.444639      2544.965438
# 191645          2.436701       -15.679495
# 43705           5.109879       381.488613
# 262703          0.039401       420.351449
# ...                  ...              ...
# 22879          -4.687871      1268.089349
# 130363         -0.482484        -4.751058
# 87099           6.663159       676.988885
# 89179          -3.010250      5047.496305
# 232699          2.536917       231.982319
#
# [11162 rows x 14 columns]

# %%
#encode the categorical columns for cleaned table
df_dummy = pd.get_dummies(df_balance)
df_dummy
# Out:
#          client_id   age      balance  average_spending  average_balance  \
# 265901   100070076  41.0   175.445269         -7.454485       203.907928
# 175317   100141910  34.0  2559.041192          0.444639      2544.965438
# 191645   100207570  34.0    94.055761          2.436701       -15.679495
# 43705    100488560  43.0   382.755389          5.109879       381.488613
# 262703   100605013  21.0   369.476219          0.039401       420.351449
# ...            ...   ...          ...               ...              ...
# 22879   1999463182  34.0  1146.101785         -4.687871      1268.089349
# 130363  1999499145  31.0    30.830676         -0.482484        -4.751058
# 87099   1999715381  24.0   792.767525          6.663159       676.988885
# 89179   1999945413  39.0  5077.753230         -3.010250      5047.496305
# 232699  1999956516  32.0   229.440915          2.536917       231.982319
#
#         job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  \
# 265901       False            False             False          False
# 175317       False            False             False          False
# 191645       False            False             False          False
# 43705         True            False             False          False
# 262703       False            False             False          False
# ...            ...              ...               ...            ...
# 22879        False             True             False          False
# 130363       False            False             False          False
# 87099        False             True             False          False
# 89179        False            False             False          False
# 232699       False             True             False          False
#
#         job_management  ...  has_deposits_no  has_deposits_yes  loan_no  \
# 265901            True  ...             True             False     True
# 175317            True  ...             True             False     True
# 191645            True  ...            False              True     True
# 43705            False  ...            False              True     True
# 262703           False  ...            False              True     True
# ...                ...  ...              ...               ...      ...
# 22879            False  ...             True             False     True
# 130363            True  ...             True             False     True
# 87099            False  ...            False              True     True
# 89179             True  ...            False              True     True
# 232699           False  ...            False              True     True
#
#         loan_yes  has_insurance_n  has_insurance_y  has_mortgage_no  \
# 265901     False             True            False             True
# 175317     False             True            False            False
# 191645     False             True            False             True
# 43705      False             True            False             True
# 262703     False            False             True             True
# ...          ...              ...              ...              ...
# 22879      False             True            False            False
# 130363     False             True            False            False
# 87099      False             True            False            False
# 89179      False             True            False             True
# 232699     False             True            False            False
#
#         has_mortgage_yes  poutcome_failure  poutcome_success
# 265901             False             False             False
# 175317              True             False             False
# 191645             False             False             False
# 43705              False              True             False
# 262703             False             False              True
# ...                  ...               ...               ...
# 22879               True             False             False
# 130363              True             False             False
# 87099               True             False             False
# 89179              False             False             False
# 232699              True              True             False
#
# [11162 rows x 36 columns]

# %%
#selecting the clients in the first campaign evaluation
df_outcome = df_balance[df_balance['poutcome'].isin(['failure', 'success'])]
df_outcome
# Out:
#          client_id   age          job  marital  education gender has_deposits  \
# 43705    100488560  43.0       admin.   single  secondary      F          yes
# 262703   100605013  21.0      student   single    primary      M          yes
# 103115   102604801  41.0   management  married  secondary      F           no
# 286857   104030718  27.0      student   single   tertiary      F          yes
# 123967   106830158  39.0   management  married    primary      F          yes
# ...            ...   ...          ...      ...        ...    ...          ...
# 257373  1996359586  40.0   unemployed   single   tertiary      M          yes
# 94327   1996474627  48.0   unemployed  married  secondary      M          yes
# 33851   1997220693  42.0       admin.  married    primary      F          yes
# 187381  1997336391  30.0   management  married   tertiary      M          yes
# 232699  1999956516  32.0  blue-collar  married  secondary      M          yes
#
#        loan has_insurance has_mortgage poutcome      balance  \
# 43705    no             n           no  failure   382.755389
# 262703   no             y           no  success   369.476219
# 103115   no             n          yes  success   184.981881
# 286857   no             n           no  success   340.821795
# 123967   no             n          yes  success  6981.709891
# ...     ...           ...          ...      ...          ...
# 257373   no             n           no  success  7957.013794
# 94327    no             n           no  success   989.012654
# 33851    no             n          yes  success  -248.224994
# 187381   no             n          yes  failure  8093.323617
# 232699   no             n          yes  failure   229.440915
#
#         average_spending  average_balance
# 43705           5.109879       381.488613
# 262703          0.039401       420.351449
# 103115         -4.462468       270.449689
# 286857          1.509400       312.058814
# 123967         -0.950741      7008.932616
# ...                  ...              ...
# 257373         -3.877861      7956.276324
# 94327           2.509168       919.751520
# 33851           0.464894      -284.422803
# 187381          1.771686      8090.524175
# 232699          2.536917       231.982319
#
# [2299 rows x 14 columns]

# %%
#change the 'poutcome' column to binary
df_outcome.loc[:, 'poutcome'] = df_outcome['poutcome'].map({'failure': 'no', 'success': 'yes'})
df_outcome
# Out:
#          client_id   age          job  marital  education gender has_deposits  \
# 43705    100488560  43.0       admin.   single  secondary      F          yes
# 262703   100605013  21.0      student   single    primary      M          yes
# 103115   102604801  41.0   management  married  secondary      F           no
# 286857   104030718  27.0      student   single   tertiary      F          yes
# 123967   106830158  39.0   management  married    primary      F          yes
# ...            ...   ...          ...      ...        ...    ...          ...
# 257373  1996359586  40.0   unemployed   single   tertiary      M          yes
# 94327   1996474627  48.0   unemployed  married  secondary      M          yes
# 33851   1997220693  42.0       admin.  married    primary      F          yes
# 187381  1997336391  30.0   management  married   tertiary      M          yes
# 232699  1999956516  32.0  blue-collar  married  secondary      M          yes
#
#        loan has_insurance has_mortgage poutcome      balance  \
# 43705    no             n           no       no   382.755389
# 262703   no             y           no      yes   369.476219
# 103115   no             n          yes      yes   184.981881
# 286857   no             n           no      yes   340.821795
# 123967   no             n          yes      yes  6981.709891
# ...     ...           ...          ...      ...          ...
# 257373   no             n           no      yes  7957.013794
# 94327    no             n           no      yes   989.012654
# 33851    no             n          yes      yes  -248.224994
# 187381   no             n          yes       no  8093.323617
# 232699   no             n          yes       no   229.440915
#
#         average_spending  average_balance
# 43705           5.109879       381.488613
# 262703          0.039401       420.351449
# 103115         -4.462468       270.449689
# 286857          1.509400       312.058814
# 123967         -0.950741      7008.932616
# ...                  ...              ...
# 257373         -3.877861      7956.276324
# 94327           2.509168       919.751520
# 33851           0.464894      -284.422803
# 187381          1.771686      8090.524175
# 232699          2.536917       231.982319
#
# [2299 rows x 14 columns]

# %%
#encode the categorical columns for the outcome table
df_dummy_one = pd.get_dummies(df_outcome)
df_dummy_one
# Out:
#          client_id   age      balance  average_spending  average_balance  \
# 43705    100488560  43.0   382.755389          5.109879       381.488613
# 262703   100605013  21.0   369.476219          0.039401       420.351449
# 103115   102604801  41.0   184.981881         -4.462468       270.449689
# 286857   104030718  27.0   340.821795          1.509400       312.058814
# 123967   106830158  39.0  6981.709891         -0.950741      7008.932616
# ...            ...   ...          ...               ...              ...
# 257373  1996359586  40.0  7957.013794         -3.877861      7956.276324
# 94327   1996474627  48.0   989.012654          2.509168       919.751520
# 33851   1997220693  42.0  -248.224994          0.464894      -284.422803
# 187381  1997336391  30.0  8093.323617          1.771686      8090.524175
# 232699  1999956516  32.0   229.440915          2.536917       231.982319
#
#         job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  \
# 43705         True            False             False          False
# 262703       False            False             False          False
# 103115       False            False             False          False
# 286857       False            False             False          False
# 123967       False            False             False          False
# ...            ...              ...               ...            ...
# 257373       False            False             False          False
# 94327        False            False             False          False
# 33851         True            False             False          False
# 187381       False            False             False          False
# 232699       False             True             False          False
#
#         job_management  ...  has_deposits_no  has_deposits_yes  loan_no  \
# 43705            False  ...            False              True     True
# 262703           False  ...            False              True     True
# 103115            True  ...             True             False     True
# 286857           False  ...            False              True     True
# 123967            True  ...            False              True     True
# ...                ...  ...              ...               ...      ...
# 257373           False  ...            False              True     True
# 94327            False  ...            False              True     True
# 33851            False  ...            False              True     True
# 187381            True  ...            False              True     True
# 232699           False  ...            False              True     True
#
#         loan_yes  has_insurance_n  has_insurance_y  has_mortgage_no  \
# 43705      False             True            False             True
# 262703     False            False             True             True
# 103115     False             True            False            False
# 286857     False             True            False             True
# 123967     False             True            False            False
# ...          ...              ...              ...              ...
# 257373     False             True            False             True
# 94327      False             True            False             True
# 33851      False             True            False            False
# 187381     False             True            False            False
# 232699     False             True            False            False
#
#         has_mortgage_yes  poutcome_no  poutcome_yes
# 43705              False         True         False
# 262703             False        False          True
# 103115              True        False          True
# 286857             False        False          True
# 123967              True        False          True
# ...                  ...          ...           ...
# 257373             False        False          True
# 94327              False        False          True
# 33851               True        False          True
# 187381              True         True         False
# 232699              True         True         False
#
# [2299 rows x 36 columns]

# %%
# Split the data into features and target variable
X = df_dummy_one[['age', 'balance', 'average_spending',
       'average_balance', 'job_admin.', 'job_blue-collar', 'job_entrepreneur',
       'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
       'job_services', 'job_student', 'job_technician', 'job_unemployed',
       'marital_divorced', 'marital_married', 'marital_single',
       'education_primary', 'education_secondary', 'education_tertiary',
       'has_deposits_no',
       'has_deposits_yes', 'loan_no', 'loan_yes', 'has_insurance_n',
       'has_insurance_y', 'has_mortgage_no', 'has_mortgage_yes']] # Features
y = df_dummy_one['poutcome_yes'] # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=40, test_size=0.3)

# %%
# Define the pipeline
pipeline_RF = Pipeline([
    ('scaler', StandardScaler()),  # Use StandardScaler as transformer
    ('classifier', RandomForestClassifier(n_estimators=400, max_features='sqrt', max_depth=5, criterion='entropy'))  # Use RandomForestClassifier as estimator
])

# Fit the pipeline to the training data
pipeline_RF.fit(X_train, y_train)

# Initializing models
kf = KFold(n_splits=5, shuffle=True, random_state=40)
kfold_scores = cross_val_score(pipeline_RF, X, y, cv=kf)
print(f"Average K-Fold CV score: {round(kfold_scores.mean() * 100, 2)}%")

# Perform cross-validation
scores = cross_val_score(pipeline_RF, X, y, cv=kf)
print(f"Average cross-validation score: {round(scores.mean() * 100, 2)}%")
# Out:
# Average K-Fold CV score: 70.51%
# Average cross-validation score: 70.73%

# %%
# Make predictions on the test set
y_pred = pipeline_RF.predict(X_test)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {round(accuracy * 100, 2)}%")

# Print the classification report
report = classification_report(y_test, y_pred)
print(f"Classification Report: \n{report}")
# Out:
# Accuracy: 70.58%
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.77      0.67      0.72       386
#         True       0.64      0.75      0.69       304
#
#     accuracy                           0.71       690
#    macro avg       0.71      0.71      0.71       690
# weighted avg       0.71      0.71      0.71       690

# %%
#saving the model
dump(pipeline_RF, 'pipeline_RF.joblib')
pipeline_RF = load('pipeline_RF.joblib')
with open('pipeline_RF.pkl', 'wb') as file:
    pickle.dump(pipeline_RF, file)
with open('pipeline_RF.pkl', 'rb') as file:
    your_random_forest_model = pickle.load(file)

# %%
#select the target for the second campaign
df_target = df_balance[~df_balance['poutcome'].isin(['failure', 'success'])]
df_target
# Out:
#          client_id   age          job   marital  education gender  \
# 265901   100070076  41.0   management  divorced   tertiary      M
# 175317   100141910  34.0   management    single   tertiary      F
# 191645   100207570  34.0   management    single   tertiary      F
# 55873    100646594  75.0      retired  divorced    primary      F
# 141023   100741497  56.0   management   married  secondary      M
# ...            ...   ...          ...       ...        ...    ...
# 209741  1999460711  53.0       admin.  divorced  secondary      M
# 22879   1999463182  34.0  blue-collar   married  secondary      M
# 130363  1999499145  31.0   management    single   tertiary      F
# 87099   1999715381  24.0  blue-collar   married  secondary      M
# 89179   1999945413  39.0   management    single   tertiary      F
#
#        has_deposits loan has_insurance has_mortgage poutcome       balance  \
# 265901           no   no             n           no     None    175.445269
# 175317           no   no             n          yes     None   2559.041192
# 191645          yes   no             n           no     None     94.055761
# 55873            no   no             n           no     None  37136.144031
# 141023           no   no             n          yes     None    240.737339
# ...             ...  ...           ...          ...      ...           ...
# 209741           no  yes             n          yes     None    259.851300
# 22879            no   no             n          yes     None   1146.101785
# 130363           no   no             n          yes     None     30.830676
# 87099           yes   no             n          yes     None    792.767525
# 89179           yes   no             n           no     None   5077.753230
#
#         average_spending  average_balance
# 265901         -7.454485       203.907928
# 175317          0.444639      2544.965438
# 191645          2.436701       -15.679495
# 55873           1.532749     37131.526158
# 141023          5.987920       228.186356
# ...                  ...              ...
# 209741          0.196719       215.601872
# 22879          -4.687871      1268.089349
# 130363         -0.482484        -4.751058
# 87099           6.663159       676.988885
# 89179          -3.010250      5047.496305
#
# [8863 rows x 14 columns]

# %%
# Select 'client_id' from the target data
client_ids = df_target['client_id']

# Select the rows with the filtered 'client_id's
X_new = df_dummy[df_dummy['client_id'].isin(client_ids)]
X_new
# Out:
#          client_id   age       balance  average_spending  average_balance  \
# 265901   100070076  41.0    175.445269         -7.454485       203.907928
# 175317   100141910  34.0   2559.041192          0.444639      2544.965438
# 191645   100207570  34.0     94.055761          2.436701       -15.679495
# 55873    100646594  75.0  37136.144031          1.532749     37131.526158
# 141023   100741497  56.0    240.737339          5.987920       228.186356
# ...            ...   ...           ...               ...              ...
# 209741  1999460711  53.0    259.851300          0.196719       215.601872
# 22879   1999463182  34.0   1146.101785         -4.687871      1268.089349
# 130363  1999499145  31.0     30.830676         -0.482484        -4.751058
# 87099   1999715381  24.0    792.767525          6.663159       676.988885
# 89179   1999945413  39.0   5077.753230         -3.010250      5047.496305
#
#         job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  \
# 265901       False            False             False          False
# 175317       False            False             False          False
# 191645       False            False             False          False
# 55873        False            False             False          False
# 141023       False            False             False          False
# ...            ...              ...               ...            ...
# 209741        True            False             False          False
# 22879        False             True             False          False
# 130363       False            False             False          False
# 87099        False             True             False          False
# 89179        False            False             False          False
#
#         job_management  ...  has_deposits_no  has_deposits_yes  loan_no  \
# 265901            True  ...             True             False     True
# 175317            True  ...             True             False     True
# 191645            True  ...            False              True     True
# 55873            False  ...             True             False     True
# 141023            True  ...             True             False     True
# ...                ...  ...              ...               ...      ...
# 209741           False  ...             True             False    False
# 22879            False  ...             True             False     True
# 130363            True  ...             True             False     True
# 87099            False  ...            False              True     True
# 89179             True  ...            False              True     True
#
#         loan_yes  has_insurance_n  has_insurance_y  has_mortgage_no  \
# 265901     False             True            False             True
# 175317     False             True            False            False
# 191645     False             True            False             True
# 55873      False             True            False             True
# 141023     False             True            False            False
# ...          ...              ...              ...              ...
# 209741      True             True            False            False
# 22879      False             True            False            False
# 130363     False             True            False            False
# 87099      False             True            False            False
# 89179      False             True            False             True
#
#         has_mortgage_yes  poutcome_failure  poutcome_success
# 265901             False             False             False
# 175317              True             False             False
# 191645             False             False             False
# 55873              False             False             False
# 141023              True             False             False
# ...                  ...               ...               ...
# 209741              True             False             False
# 22879               True             False             False
# 130363              True             False             False
# 87099               True             False             False
# 89179              False             False             False
#
# [8863 rows x 36 columns]

# %%
# Get the feature names from the training data
feature_names = X_train.columns
feature_names
# Out:
# Index(['age', 'balance', 'average_spending', 'average_balance', 'job_admin.',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'marital_divorced',
#        'marital_married', 'marital_single', 'education_primary',
#        'education_secondary', 'education_tertiary', 'has_deposits_no',
#        'has_deposits_yes', 'loan_no', 'loan_yes', 'has_insurance_n',
#        'has_insurance_y', 'has_mortgage_no', 'has_mortgage_yes'],
#       dtype='object')

# %%
# Filter the new data to include only the matching feature names
X_new_filtered = X_new[feature_names]
X_new_filtered
# Out:
#          age       balance  average_spending  average_balance  job_admin.  \
# 265901  41.0    175.445269         -7.454485       203.907928       False
# 175317  34.0   2559.041192          0.444639      2544.965438       False
# 191645  34.0     94.055761          2.436701       -15.679495       False
# 55873   75.0  37136.144031          1.532749     37131.526158       False
# 141023  56.0    240.737339          5.987920       228.186356       False
# ...      ...           ...               ...              ...         ...
# 209741  53.0    259.851300          0.196719       215.601872        True
# 22879   34.0   1146.101785         -4.687871      1268.089349       False
# 130363  31.0     30.830676         -0.482484        -4.751058       False
# 87099   24.0    792.767525          6.663159       676.988885       False
# 89179   39.0   5077.753230         -3.010250      5047.496305       False
#
#         job_blue-collar  job_entrepreneur  job_housemaid  job_management  \
# 265901            False             False          False            True
# 175317            False             False          False            True
# 191645            False             False          False            True
# 55873             False             False          False           False
# 141023            False             False          False            True
# ...                 ...               ...            ...             ...
# 209741            False             False          False           False
# 22879              True             False          False           False
# 130363            False             False          False            True
# 87099              True             False          False           False
# 89179             False             False          False            True
#
#         job_retired  ...  education_secondary  education_tertiary  \
# 265901        False  ...                False                True
# 175317        False  ...                False                True
# 191645        False  ...                False                True
# 55873          True  ...                False               False
# 141023        False  ...                 True               False
# ...             ...  ...                  ...                 ...
# 209741        False  ...                 True               False
# 22879         False  ...                 True               False
# 130363        False  ...                False                True
# 87099         False  ...                 True               False
# 89179         False  ...                False                True
#
#         has_deposits_no  has_deposits_yes  loan_no  loan_yes  has_insurance_n  \
# 265901             True             False     True     False             True
# 175317             True             False     True     False             True
# 191645            False              True     True     False             True
# 55873              True             False     True     False             True
# 141023             True             False     True     False             True
# ...                 ...               ...      ...       ...              ...
# 209741             True             False    False      True             True
# 22879              True             False     True     False             True
# 130363             True             False     True     False             True
# 87099             False              True     True     False             True
# 89179             False              True     True     False             True
#
#         has_insurance_y  has_mortgage_no  has_mortgage_yes
# 265901            False             True             False
# 175317            False            False              True
# 191645            False             True             False
# 55873             False             True             False
# 141023            False            False              True
# ...                 ...              ...               ...
# 209741            False            False              True
# 22879             False            False              True
# 130363            False            False              True
# 87099             False            False              True
# 89179             False             True             False
#
# [8863 rows x 29 columns]

# %%
# Make predictions with your model using the filtered new data
predictions = pipeline_RF.predict_proba(X_new_filtered)[:, 1]

# Add the predictions as a new column in the DataFrame
X_new_pred = X_new_filtered.copy()
X_new_pred.loc[:, 'predictions'] = predictions
X_new_pred
# Out:
#          age       balance  average_spending  average_balance  job_admin.  \
# 265901  41.0    175.445269         -7.454485       203.907928       False
# 175317  34.0   2559.041192          0.444639      2544.965438       False
# 191645  34.0     94.055761          2.436701       -15.679495       False
# 55873   75.0  37136.144031          1.532749     37131.526158       False
# 141023  56.0    240.737339          5.987920       228.186356       False
# ...      ...           ...               ...              ...         ...
# 209741  53.0    259.851300          0.196719       215.601872        True
# 22879   34.0   1146.101785         -4.687871      1268.089349       False
# 130363  31.0     30.830676         -0.482484        -4.751058       False
# 87099   24.0    792.767525          6.663159       676.988885       False
# 89179   39.0   5077.753230         -3.010250      5047.496305       False
#
#         job_blue-collar  job_entrepreneur  job_housemaid  job_management  \
# 265901            False             False          False            True
# 175317            False             False          False            True
# 191645            False             False          False            True
# 55873             False             False          False           False
# 141023            False             False          False            True
# ...                 ...               ...            ...             ...
# 209741            False             False          False           False
# 22879              True             False          False           False
# 130363            False             False          False            True
# 87099              True             False          False           False
# 89179             False             False          False            True
#
#         job_retired  ...  education_tertiary  has_deposits_no  \
# 265901        False  ...                True             True
# 175317        False  ...                True             True
# 191645        False  ...                True            False
# 55873          True  ...               False             True
# 141023        False  ...               False             True
# ...             ...  ...                 ...              ...
# 209741        False  ...               False             True
# 22879         False  ...               False             True
# 130363        False  ...                True             True
# 87099         False  ...               False            False
# 89179         False  ...                True            False
#
#         has_deposits_yes  loan_no  loan_yes  has_insurance_n  has_insurance_y  \
# 265901             False     True     False             True            False
# 175317             False     True     False             True            False
# 191645              True     True     False             True            False
# 55873              False     True     False             True            False
# 141023             False     True     False             True            False
# ...                  ...      ...       ...              ...              ...
# 209741             False    False      True             True            False
# 22879              False     True     False             True            False
# 130363             False     True     False             True            False
# 87099               True     True     False             True            False
# 89179               True     True     False             True            False
#
#         has_mortgage_no  has_mortgage_yes  predictions
# 265901             True             False     0.286743
# 175317            False              True     0.155374
# 191645             True             False     0.585249
# 55873              True             False     0.505362
# 141023            False              True     0.139255
# ...                 ...               ...          ...
# 209741            False              True     0.157856
# 22879             False              True     0.093717
# 130363            False              True     0.145024
# 87099             False              True     0.485644
# 89179              True             False     0.677774
#
# [8863 rows x 30 columns]

# %%
# Sort the DataFrame by the 'predictions' column in descending order
X_new_pred = X_new_pred.sort_values('predictions', ascending=False)
X_new_pred
# Out:
#          age       balance  average_spending  average_balance  job_admin.  \
# 2469    79.0    144.187196          5.246050        75.581612       False
# 101945  66.0    114.029128          5.654960        37.216584       False
# 225575  78.0    550.918659          2.935134       552.989126       False
# 196299  69.0    208.267122          3.242535       230.139893       False
# 205529  74.0  29066.902642          2.040186     29065.034642       False
# ...      ...           ...               ...              ...         ...
# 203917  33.0   -339.883514         -3.943638      -300.911123       False
# 249885  32.0   -285.315750         -5.025765      -195.839370       False
# 160731  37.0   -364.069743          2.760169      -398.458759       False
# 64999   40.0   -332.928093         -0.099938      -323.258860       False
# 174407  31.0   -768.563891         -2.813237      -719.510839       False
#
#         job_blue-collar  job_entrepreneur  job_housemaid  job_management  \
# 2469              False             False          False           False
# 101945            False             False          False           False
# 225575            False             False          False           False
# 196299            False             False          False           False
# 205529            False             False          False           False
# ...                 ...               ...            ...             ...
# 203917             True             False          False           False
# 249885             True             False          False           False
# 160731             True             False          False           False
# 64999              True             False          False           False
# 174407             True             False          False           False
#
#         job_retired  ...  education_tertiary  has_deposits_no  \
# 2469           True  ...               False            False
# 101945         True  ...               False            False
# 225575         True  ...               False            False
# 196299         True  ...                True            False
# 205529         True  ...               False            False
# ...             ...  ...                 ...              ...
# 203917        False  ...               False             True
# 249885        False  ...               False             True
# 160731        False  ...               False             True
# 64999         False  ...               False             True
# 174407        False  ...               False             True
#
#         has_deposits_yes  loan_no  loan_yes  has_insurance_n  has_insurance_y  \
# 2469                True     True     False             True            False
# 101945              True     True     False             True            False
# 225575              True     True     False             True            False
# 196299              True     True     False             True            False
# 205529              True     True     False             True            False
# ...                  ...      ...       ...              ...              ...
# 203917             False    False      True            False             True
# 249885             False    False      True             True            False
# 160731             False    False      True             True            False
# 64999              False    False      True             True            False
# 174407             False    False      True             True            False
#
#         has_mortgage_no  has_mortgage_yes  predictions
# 2469               True             False     0.759048
# 101945             True             False     0.752783
# 225575             True             False     0.750691
# 196299             True             False     0.747949
# 205529             True             False     0.747855
# ...                 ...               ...          ...
# 203917            False              True     0.032044
# 249885            False              True     0.031657
# 160731            False              True     0.031295
# 64999             False              True     0.030618
# 174407            False              True     0.029636
#
# [8863 rows x 30 columns]

# %%
# Select only the top 3000 success_probablity score clients
top_3000_target = X_new_pred.head(3000)
top_3000_target
# Out:
#          age       balance  average_spending  average_balance  job_admin.  \
# 2469    79.0    144.187196          5.246050        75.581612       False
# 101945  66.0    114.029128          5.654960        37.216584       False
# 225575  78.0    550.918659          2.935134       552.989126       False
# 196299  69.0    208.267122          3.242535       230.139893       False
# 205529  74.0  29066.902642          2.040186     29065.034642       False
# ...      ...           ...               ...              ...         ...
# 160679  34.0    156.207742          0.862121        83.603689       False
# 51219   29.0    289.546048         -1.684720       268.398573       False
# 232257  34.0   2693.385596         -6.943313      2729.267295       False
# 80495   33.0    199.894151          1.541931       200.418870       False
# 230125  45.0     58.551702          0.619869         5.076148       False
#
#         job_blue-collar  job_entrepreneur  job_housemaid  job_management  \
# 2469              False             False          False           False
# 101945            False             False          False           False
# 225575            False             False          False           False
# 196299            False             False          False           False
# 205529            False             False          False           False
# ...                 ...               ...            ...             ...
# 160679            False             False          False           False
# 51219              True             False          False           False
# 232257            False             False          False           False
# 80495             False             False          False           False
# 230125            False             False          False           False
#
#         job_retired  ...  education_tertiary  has_deposits_no  \
# 2469           True  ...               False            False
# 101945         True  ...               False            False
# 225575         True  ...               False            False
# 196299         True  ...                True            False
# 205529         True  ...               False            False
# ...             ...  ...                 ...              ...
# 160679        False  ...               False            False
# 51219         False  ...               False            False
# 232257        False  ...               False            False
# 80495         False  ...               False            False
# 230125        False  ...               False            False
#
#         has_deposits_yes  loan_no  loan_yes  has_insurance_n  has_insurance_y  \
# 2469                True     True     False             True            False
# 101945              True     True     False             True            False
# 225575              True     True     False             True            False
# 196299              True     True     False             True            False
# 205529              True     True     False             True            False
# ...                  ...      ...       ...              ...              ...
# 160679              True     True     False             True            False
# 51219               True     True     False             True            False
# 232257              True     True     False             True            False
# 80495               True     True     False             True            False
# 230125              True     True     False             True            False
#
#         has_mortgage_no  has_mortgage_yes  predictions
# 2469               True             False     0.759048
# 101945             True             False     0.752783
# 225575             True             False     0.750691
# 196299             True             False     0.747949
# 205529             True             False     0.747855
# ...                 ...               ...          ...
# 160679            False              True     0.475047
# 51219             False              True     0.475024
# 232257            False              True     0.474805
# 80495             False              True     0.474805
# 230125            False              True     0.474653
#
# [3000 rows x 30 columns]

# %%
# Save the 'client_id's to a CSV file
top_3000_target.to_csv('top_3000_potencial_client_RF__.csv', index=False)
